# %% [markdown]
# <a href="https://colab.research.google.com/github/slyofzero/Twitter-NLP/blob/main/Twitter_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/slyofzero/Twitter-BoycottQatarAirways-NLP/main/Hydrator%20Tweets%20data/tweets.csv")
df.head()
# Out:
#    coordinates                      created_at  \
# 0          NaN  Mon Jun 06 15:15:37 +0000 2022
# 1          NaN  Mon Jun 06 15:15:00 +0000 2022
# 2          NaN  Mon Jun 06 15:16:08 +0000 2022
# 3          NaN  Mon Jun 06 15:13:19 +0000 2022
# 4          NaN  Mon Jun 06 14:45:43 +0000 2022
#
#                           hashtags  \
# 0              BoycottQatarAirways
# 1                              NaN
# 2                     QatarAirways
# 3  BoycottQatarAirways SaudiArabia
# 4              BoycottQatarAirways
#
#                                                media urls  favorite_count  \
# 0                                                NaN  NaN               0
# 1                                                NaN  NaN               0
# 2                                                NaN  NaN               0
# 3  https://twitter.com/alindasangma/status/153379...  NaN               0
# 4                                                NaN  NaN               0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8605 entries, 0 to 8604
# Data columns (total 35 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   coordinates                 0 non-null      float64
#  1   created_at                  8605 non-null   object
#  2   hashtags                    6792 non-null   object
#  3   media                       1636 non-null   object
#  4   urls                        387 non-null    object
#  5   favorite_count              8605 non-null   int64
#  6   id                          8605 non-null   int64
#  7   in_reply_to_screen_name     251 non-null    object
#  8   in_reply_to_status_id       229 non-null    float64
#  9   in_reply_to_user_id         251 non-null    float64
#  10  lang                        8605 non-null   object
#  11  place                       22 non-null     object
#  12  possibly_sensitive          2013 non-null   object
# ...

# %%
df["text"]
# Out:
# 0       India should teach a lesson to this tiny natio...
# 1       When MF Hussain &amp; Zakir Naik both insulted...
# 2       Deleted the #QatarAirways app and also cancele...
# 3       Show your Support:\n#BoycottQatarAirways   #Sa...
# 4       I have bought air tickets many a times but I s...
#                               ...
# 8600    Two-faced #Qatar!\n\nQatar awarded MF Husain c...
# 8601    Beauty of Peaceful community  \nEarth is flat\...
# 8602    Show your Support:\n#BoycottQatarAirways   #Sa...
# 8603    @goelgauravbjp Blue tickers will have to boyco...
# 8604    Rt max #BoycottQatarAirways https://t.co/L2zZx...
# Name: text, Length: 8605, dtype: object
